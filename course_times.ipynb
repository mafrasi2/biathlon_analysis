# %%
import biathlonresults
import itertools
import pandas
import requests
import shutil
from datetime import timedelta, datetime
from pathlib import Path
from tika import parser

# %%
events = biathlonresults.events(1920, 1)
competitions = {}
for event in events:
    competitions[event["EventId"]] = biathlonresults.competitions(event["EventId"])

# %% [markdown]
# We limit ourselves to men's competitions. Relays are a bit harder to compare than other competitions so we remove them as well:

# %%
men_non_relays = []
for _, comps in competitions.items():
    for comp in comps:
        desc = comp["Description"]
        if desc.startswith("Men") and not "Relay" in desc:
            men_non_relays.append(comp)

# %% [markdown]
# Download the analysis pdfs, which contain course times per athlete:

# %%
pdf_dir = Path("pdfs")
pdf_dir.mkdir(exist_ok=True)
pdfs = {}
if pdf_dir.exists(): # use cached pdfs
    for pdf in pdf_dir.iterdir():
        pdfs[pdf.stem] = pdf
else:
    for comp in men_non_relays:
        reports = biathlonresults.api._request("Reports2", {"RaceId": comp["RaceId"]})
        for report in reports["Reports"]:
            if report["Description"] == "COMPETITION ANALYSIS":
                break
        else:
            continue
        pdf_file = pdf_dir / f"{comp['RaceId']}.pdf"

        r = requests.get(report["URL"], stream=True)
        r.raise_for_status()
        with pdf_file.open("wb") as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
        pdfs[comp["RaceId"]] = pdf_file

# %% [markdown]
# Now parse the pdfs (this is ugly, but I don't know a better source for the course times):

# %%
def parse_time(time):
    try:
        time = datetime.strptime(time, "%H:%M:%S.%f")
    except ValueError:
        try:
            time = datetime.strptime(time, "%M:%S.%f")
        except ValueError:
            return None
    return timedelta(hours=time.hour, minutes=time.minute, seconds=time.second, microseconds=time.microsecond)

def parse_pdf(pdf_file):
    raw_data = parser.from_file(str(pdf_file))
    next_rank = 1
    last_rank = None
    current_athlete = None
    course_times = {}
    for line in raw_data["content"].split("\n"):
        line = line.split()
        if not line:
            continue
        if line[0] == "Did":
            # Did not start and Did not finish
            break
        elif line[0] == f"{next_rank}" or line[0] == f"{last_rank}":
            if line[0] == f"{next_rank}":
                last_rank = next_rank
            next_rank += 1
            current_athlete = " ".join(line[2:-5])
        elif line[0] == "Course" and line[1] == "Time":
            if not current_athlete:
                assert current_athlete
            times = []
            for elem in line:
                time = parse_time(elem)
                if time:
                    times.append(time)
            course_times[current_athlete] = times
            current_athlete = None
    return course_times
            
course_times = {}
for raceid, pdf in pdfs.items():
    course_times[raceid] = parse_pdf(pdf)

# %% [markdown]
# Now we select which times we want to analyze. For mass starts and pursuits, we remove the final lap since not all athletes have to give their best then. For the other formats, we use the official total time:

# %%
from pprint import pprint
for comp, athletes in course_times.items():
    if comp.endswith("MS") or comp.endswith("PU"):
        course_times[comp] = {athlete: sum(times[:-2], timedelta()) for athlete, times in athletes.items()}
    else:
        course_times[comp] = {athlete: times[-1] for athlete, times in athletes.items()}

# %% [markdown]
# We want to compare the difference of the top athletes from the mean. For the athletes we are interested in, this difference would be higher in competitions with a large number of athletes, so we wouldn't be able to compare differences across competitions.
#
# Therefore, we have to limit the analysis to only the top 30 athletes in each competition:

# %%
top30 = {}
for comp, times in course_times.items():
    # works only for python 3.7+ since the dict must be ordered
    top30[comp] = dict(itertools.islice(times.items(), 30))

# %% [markdown]
# Now, we convert to pandas for easier analysis (athletes in rows and competitions in columns):

# %%
athletes = set()
athletes = athletes.union(*[athletes for _, athletes in top30.items()])
athletes = list(athletes) # we need an order
table = {}
athlete_rows = {}
for comp, times in top30.items():
    col = []
    for athlete in athletes:
        if athlete in times:
             # working with timedelta is a bit annoying in pandas, so we just use seconds
            time = times[athlete].total_seconds()
            col.append(time)
        else:
            col.append(None)
    table[comp] = col
df = pandas.DataFrame(table, index=athletes)
df
# Out:
#                              BT1920SWRLCP02SMSP  BT1920SWRLCP06SMIN  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                              NaN              2774.7
# CHRISTIANSEN Vetle Sjaastad              1417.3              2727.4
# OTCENAS Martin                              NaN                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                           NaN                 NaN
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                        1424.1              2739.7
# JACQUELIN Emilien                        1413.8                 NaN
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCP01SMIN  BT1920SWRLCP01SMSP  \
# BIRKELAND Lars Helge                        NaN              1405.9
# BORMOLINI Thomas                         3163.2              1401.5
# MORAVEC Ondrej                           3156.7                 NaN
# CHRISTIANSEN Vetle Sjaastad                 NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                        3079.7                 NaN
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                           NaN              1383.2
# JACQUELIN Emilien                        3020.3              1347.1
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCH__SMSP  BT1920SWRLCP03SMPU  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                              NaN                 NaN
# CHRISTIANSEN Vetle Sjaastad                 NaN              1298.5
# OTCENAS Martin                           1327.6                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                        1303.7              1347.9
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                           NaN                 NaN
# JACQUELIN Emilien                        1274.8              1300.2
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCP05SMPU  BT1920SWRLCP04SMSP  \
# BIRKELAND Lars Helge                     1374.9                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                           1387.9              1503.0
# CHRISTIANSEN Vetle Sjaastad              1360.5              1447.4
# OTCENAS Martin                              NaN                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                           NaN                 NaN
# DOHERTY Sean                                NaN              1512.3
# GUIGONNAT Antonin                        1354.7                 NaN
# JACQUELIN Emilien                        1331.6              1434.9
# ANDERSEN Aleksander Fjeld                1362.9                 NaN
#
#                              BT1920SWRLCP05SMSP  BT1920SWRLCP02SMPU  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                           1320.5                 NaN
# CHRISTIANSEN Vetle Sjaastad              1261.7                 NaN
# OTCENAS Martin                              NaN                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                           NaN                 NaN
# DOHERTY Sean                             1302.8                 NaN
# GUIGONNAT Antonin                        1292.4              1365.1
# JACQUELIN Emilien                        1291.5              1327.9
# ANDERSEN Aleksander Fjeld                   NaN              1380.0
#
#                              BT1920SWRLCP06SMMS  BT1920SWRLCP03SMMS  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                              NaN                 NaN
# CHRISTIANSEN Vetle Sjaastad              1593.4              1921.2
# OTCENAS Martin                              NaN                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                           NaN              1974.7
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                        1636.0                 NaN
# JACQUELIN Emilien                        1616.0              1865.5
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCP04SMMS  BT1920SWRLCP03SMSP
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                           1928.3                 NaN
# CHRISTIANSEN Vetle Sjaastad              1855.4              1329.8
# OTCENAS Martin                              NaN                 NaN
# ...                                         ...                 ...
# PONSILUOMA Martin                           NaN              1344.4
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                           NaN                 NaN
# JACQUELIN Emilien                        1932.3              1339.4
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
# [73 rows x 14 columns]

# %% [markdown]
# Construct the relative distance from the mean in each competition per athlete and then the mean per athlete across all competitions:

# %%
diff_from_mean = df-df.mean()
rel_per_comp_and_athlete = diff_from_mean / df.mean()
rel_mean_per_athlete = rel_per_comp_and_athlete.mean(axis=1)

# %% [markdown]
# For example, Johannes is on average 3.0% faster than the mean athlete:

# %%
rel_mean_per_athlete.sort_values()
# Out:
# BOE Johannes Thingnes    -0.029561
# FILLON MAILLET Quentin   -0.024592
# FOURCADE Martin          -0.023705
# BOE Tarjei               -0.017247
# DALE Johannes            -0.015299
#                             ...
# TRSAN Rok                 0.033569
# GUZIK Grzegorz            0.035970
# WIESTNER Sera n           0.036534
# BAUER Klemen              0.036923
# BABIKOV Anton             0.044892
# Length: 73, dtype: float64

# %% [markdown]
# Now, let's see how much have they differed from their own mean per competition:

# %%
rel_improv = (-1*rel_per_comp_and_athlete).add(rel_mean_per_athlete, axis=0)

# %% [markdown]
# For example, Matvey Eliseev was 1.1% better than his average in BT1920SWRLCP02SMSP (sprint in Hochfilzen):

# %%
pandas.set_option('display.max_rows', len(rel_improv))
rel_improv
# Out:
#                              BT1920SWRLCP02SMSP  BT1920SWRLCP06SMIN  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                              NaN            0.008434
# CHRISTIANSEN Vetle Sjaastad           -0.013345           -0.006098
# OTCENAS Martin                              NaN                 NaN
# SAMUELSSON Sebastian                        NaN                 NaN
# HOFER Lukas                            0.000924           -0.010249
# PIDRUCHNYI Dmytro                      0.008244           -0.009311
# HORN Philipp                           0.001407            0.009081
# BOE Tarjei                             0.002733            0.000380
# LAPSHIN Timofei                        0.016968                 NaN
# BOE Johannes Thingnes                 -0.003140           -0.002550
# DUDCHENKO Anton                       -0.012615                 NaN
# PRYMA Artem                                 NaN            0.012635
# CLAUDE Fabien                         -0.005976            0.005260
# LATYPOV Eduard                              NaN           -0.006687
# TRSAN Rok                                   NaN                 NaN
# ILIEV Vladimir                              NaN            0.002473
# FEMLING Peppe                               NaN                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# REES Roman                                  NaN                 NaN
# FAK Jakov                             -0.006411            0.005704
# NELIN Jesper                                NaN                 NaN
# SEPPALA Tero                                NaN                 NaN
# PEIFFER Arnd                          -0.006002                 NaN
# NAWRATH Philipp                             NaN            0.003517
# DOLL Benedikt                          0.003233            0.005852
# EBERHARD Julian                       -0.005411                 NaN
# NORDGREN Leif                               NaN            0.006340
# KRCMAR Michal                               NaN                 NaN
# LEITNER Felix                         -0.007840                 NaN
# WINDISCH Dominik                       0.003538                 NaN
# DOLDER Mario                                NaN                 NaN
# ANEV Krasimir                               NaN                 NaN
# SCHEMPP Simon                          0.011432                 NaN
# LESSER Erik                                 NaN           -0.002082
# EDER Simon                                  NaN           -0.004614
# WEGER Benjamin                              NaN           -0.003453
# YALIOTNAU Raman                             NaN                 NaN
# SMOLSKI Anton                               NaN                 NaN
# FILLON MAILLET Quentin                 0.001686            0.010086
# CHENG Fangming                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# MALYSHKO Dmitry                        0.002368                 NaN
# ELISEEV Matvey                         0.011096                 NaN
# BAUER Klemen                           0.000000                 NaN
# YEREMIN Roman                               NaN                 NaN
# BJOENTEGAARD Erlend                   -0.027817                 NaN
# BABIKOV Anton                               NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# STVRTECKY Jakub                        0.010085                 NaN
# STRELTSOV Kirill                            NaN           -0.009977
# GUZIK Grzegorz                              NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# FOURCADE Martin                       -0.007689            0.003488
# KUEHN Johannes                         0.002992           -0.001459
# VARABEI Maksim                              NaN            0.000000
# WIESTNER Sera n                             NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN           -0.000295
# LANGER Thierry                         0.000766                 NaN
# LOGINOV Alexander                     -0.000584            0.001916
# DESTHIEUX Simon                        0.009086           -0.001090
# DALE Johannes                         -0.006219            0.014633
# BOCHARNIKOV Sergey                          NaN           -0.001810
# GOW Scott                                   NaN            0.002168
# GARANICHEV Evgeniy                          NaN                 NaN
# CLAUDE Florent                              NaN                 NaN
# PONSILUOMA Martin                           NaN                 NaN
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                     -0.001071            0.006497
# JACQUELIN Emilien                     -0.011204                 NaN
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCP01SMIN  BT1920SWRLCP01SMSP  \
# BIRKELAND Lars Helge                        NaN           -0.007846
# BORMOLINI Thomas                      -0.001949            0.001949
# MORAVEC Ondrej                        -0.005704                 NaN
# CHRISTIANSEN Vetle Sjaastad                 NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# SAMUELSSON Sebastian                  -0.020939            0.003038
# HOFER Lukas                            0.037008           -0.020932
# PIDRUCHNYI Dmytro                      0.008754                 NaN
# HORN Philipp                          -0.014874                 NaN
# BOE Tarjei                             0.005386            0.010916
# LAPSHIN Timofei                             NaN                 NaN
# BOE Johannes Thingnes                 -0.028048            0.004748
# DUDCHENKO Anton                             NaN                 NaN
# PRYMA Artem                                 NaN                 NaN
# CLAUDE Fabien                          0.005566           -0.008979
# LATYPOV Eduard                              NaN            0.006687
# TRSAN Rok                                   NaN                 NaN
# ILIEV Vladimir                              NaN            0.016278
# FEMLING Peppe                               NaN                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# REES Roman                                  NaN                 NaN
# FAK Jakov                                   NaN           -0.009555
# NELIN Jesper                                NaN                 NaN
# SEPPALA Tero                          -0.003196                 NaN
# PEIFFER Arnd                                NaN                 NaN
# NAWRATH Philipp                             NaN                 NaN
# DOLL Benedikt                          0.016587            0.007243
# EBERHARD Julian                       -0.018019            0.009833
# NORDGREN Leif                               NaN                 NaN
# KRCMAR Michal                          0.011492           -0.006167
# LEITNER Felix                          0.011191                 NaN
# WINDISCH Dominik                            NaN                 NaN
# DOLDER Mario                                NaN            0.000000
# ANEV Krasimir                         -0.020967                 NaN
# SCHEMPP Simon                               NaN                 NaN
# LESSER Erik                                 NaN                 NaN
# EDER Simon                             0.006513                 NaN
# WEGER Benjamin                         0.007217                 NaN
# YALIOTNAU Raman                             NaN           -0.004985
# SMOLSKI Anton                               NaN                 NaN
# FILLON MAILLET Quentin                 0.021959           -0.010917
# CHENG Fangming                        -0.002473                 NaN
# VACLAVIK Adam                               NaN            0.000000
# MALYSHKO Dmitry                             NaN                 NaN
# ELISEEV Matvey                        -0.001448            0.012791
# BAUER Klemen                                NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# BJOENTEGAARD Erlend                   -0.009110            0.004491
# BABIKOV Anton                          0.000000                 NaN
# LANDERTINGER Dominik                   0.000000                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# STRELTSOV Kirill                            NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# FOURCADE Martin                        0.023985            0.009506
# KUEHN Johannes                              NaN            0.012069
# VARABEI Maksim                              NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN            0.004910
# LANGER Thierry                              NaN                 NaN
# LOGINOV Alexander                     -0.000018            0.002915
# DESTHIEUX Simon                        0.029218           -0.001102
# DALE Johannes                               NaN           -0.001770
# BOCHARNIKOV Sergey                          NaN            0.007937
# GOW Scott                                   NaN                 NaN
# GARANICHEV Evgeniy                     0.017375           -0.023785
# CLAUDE Florent                         0.000798            0.004735
# PONSILUOMA Martin                      0.007092                 NaN
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                           NaN           -0.005246
# JACQUELIN Emilien                      0.006545            0.003746
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCH__SMSP  BT1920SWRLCP03SMPU  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                              NaN                 NaN
# CHRISTIANSEN Vetle Sjaastad                 NaN            0.009859
# OTCENAS Martin                         0.000000                 NaN
# SAMUELSSON Sebastian                   0.006635                 NaN
# HOFER Lukas                           -0.008526            0.006365
# PIDRUCHNYI Dmytro                      0.010047            0.009167
# HORN Philipp                           0.021478           -0.002951
# BOE Tarjei                             0.001890           -0.006041
# LAPSHIN Timofei                        0.027900            0.015118
# BOE Johannes Thingnes                 -0.003275            0.001266
# DUDCHENKO Anton                             NaN            0.012724
# PRYMA Artem                           -0.006437            0.004088
# CLAUDE Fabien                               NaN                 NaN
# LATYPOV Eduard                              NaN                 NaN
# TRSAN Rok                              0.003672           -0.003672
# ILIEV Vladimir                              NaN           -0.006765
# FEMLING Peppe                          0.000000                 NaN
# PORSHNEV Nikita                       -0.008637                 NaN
# REES Roman                                  NaN                 NaN
# FAK Jakov                                   NaN                 NaN
# NELIN Jesper                          -0.001522                 NaN
# SEPPALA Tero                                NaN                 NaN
# PEIFFER Arnd                           0.003058            0.003882
# NAWRATH Philipp                             NaN                 NaN
# DOLL Benedikt                          0.010622           -0.009755
# EBERHARD Julian                        0.000577           -0.006580
# NORDGREN Leif                               NaN                 NaN
# KRCMAR Michal                               NaN            0.011670
# LEITNER Felix                         -0.001905                 NaN
# WINDISCH Dominik                            NaN            0.013858
# DOLDER Mario                                NaN                 NaN
# ANEV Krasimir                          0.020967                 NaN
# SCHEMPP Simon                               NaN            0.016954
# LESSER Erik                                 NaN                 NaN
# EDER Simon                                  NaN           -0.001584
# WEGER Benjamin                              NaN                 NaN
# YALIOTNAU Raman                             NaN                 NaN
# SMOLSKI Anton                          0.003557                 NaN
# FILLON MAILLET Quentin                 0.014759           -0.008556
# CHENG Fangming                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# MALYSHKO Dmitry                             NaN                 NaN
# ELISEEV Matvey                         0.007733           -0.034598
# BAUER Klemen                                NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# BJOENTEGAARD Erlend                         NaN            0.015116
# BABIKOV Anton                               NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# STRELTSOV Kirill                            NaN                 NaN
# GUZIK Grzegorz                         0.000000                 NaN
# STROLIA Vytautas                       0.001653                 NaN
# LABASTAU Mikita                             NaN           -0.009483
# FOURCADE Martin                       -0.003568           -0.006235
# KUEHN Johannes                              NaN           -0.000234
# VARABEI Maksim                              NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN                 NaN
# LANGER Thierry                              NaN                 NaN
# LOGINOV Alexander                      0.027827           -0.020090
# DESTHIEUX Simon                       -0.011492           -0.010649
# DALE Johannes                         -0.002618           -0.005149
# BOCHARNIKOV Sergey                          NaN                 NaN
# GOW Scott                             -0.000558                 NaN
# GARANICHEV Evgeniy                          NaN                 NaN
# CLAUDE Florent                              NaN            0.000974
# PONSILUOMA Martin                      0.007290           -0.007880
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                           NaN                 NaN
# JACQUELIN Emilien                      0.009626            0.008240
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCP05SMPU  BT1920SWRLCP04SMSP  \
# BIRKELAND Lars Helge                   0.007846                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                        -0.001025            0.001571
# CHRISTIANSEN Vetle Sjaastad           -0.012639            0.007501
# OTCENAS Martin                              NaN                 NaN
# SAMUELSSON Sebastian                   0.004191                 NaN
# HOFER Lukas                                 NaN                 NaN
# PIDRUCHNYI Dmytro                           NaN                 NaN
# HORN Philipp                                NaN           -0.000845
# BOE Tarjei                            -0.004530           -0.004855
# LAPSHIN Timofei                             NaN                 NaN
# BOE Johannes Thingnes                       NaN                 NaN
# DUDCHENKO Anton                       -0.000109                 NaN
# PRYMA Artem                            0.005785            0.000085
# CLAUDE Fabien                         -0.011801                 NaN
# LATYPOV Eduard                              NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# ILIEV Vladimir                              NaN                 NaN
# FEMLING Peppe                               NaN                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# REES Roman                             0.011340                 NaN
# FAK Jakov                              0.012332           -0.010149
# NELIN Jesper                                NaN           -0.008508
# SEPPALA Tero                                NaN                 NaN
# PEIFFER Arnd                           0.001800            0.004777
# NAWRATH Philipp                        0.001355                 NaN
# DOLL Benedikt                         -0.025061                 NaN
# EBERHARD Julian                       -0.003171                 NaN
# NORDGREN Leif                               NaN           -0.006340
# KRCMAR Michal                         -0.004894                 NaN
# LEITNER Felix                               NaN                 NaN
# WINDISCH Dominik                            NaN                 NaN
# DOLDER Mario                                NaN                 NaN
# ANEV Krasimir                               NaN                 NaN
# SCHEMPP Simon                               NaN                 NaN
# LESSER Erik                                 NaN                 NaN
# EDER Simon                                  NaN           -0.016424
# WEGER Benjamin                              NaN           -0.000166
# YALIOTNAU Raman                        0.003888            0.001203
# SMOLSKI Anton                               NaN           -0.003557
# FILLON MAILLET Quentin                -0.008634            0.000558
# CHENG Fangming                              NaN            0.002473
# VACLAVIK Adam                               NaN                 NaN
# MALYSHKO Dmitry                             NaN                 NaN
# ELISEEV Matvey                         0.006570            0.032213
# BAUER Klemen                                NaN                 NaN
# YEREMIN Roman                               NaN            0.000000
# BJOENTEGAARD Erlend                   -0.010236            0.018183
# BABIKOV Anton                               NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# STRELTSOV Kirill                            NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# STROLIA Vytautas                            NaN            0.001042
# LABASTAU Mikita                        0.009483                 NaN
# FOURCADE Martin                       -0.005684            0.014542
# KUEHN Johannes                        -0.002204            0.014068
# VARABEI Maksim                              NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# RASTORGUJEVS Andrejs                  -0.000205            0.009911
# LANGER Thierry                              NaN                 NaN
# LOGINOV Alexander                      0.004851            0.013443
# DESTHIEUX Simon                       -0.014157            0.005149
# DALE Johannes                         -0.000667            0.009444
# BOCHARNIKOV Sergey                          NaN            0.009366
# GOW Scott                                   NaN           -0.001610
# GARANICHEV Evgeniy                     0.007063            0.007300
# CLAUDE Florent                              NaN                 NaN
# PONSILUOMA Martin                           NaN                 NaN
# DOHERTY Sean                                NaN           -0.007689
# GUIGONNAT Antonin                      0.008720                 NaN
# JACQUELIN Emilien                      0.008318            0.015648
# ANDERSEN Aleksander Fjeld              0.010874                 NaN
#
#                              BT1920SWRLCP05SMSP  BT1920SWRLCP02SMPU  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                        -0.003097                 NaN
# CHRISTIANSEN Vetle Sjaastad            0.010727                 NaN
# OTCENAS Martin                              NaN                 NaN
# SAMUELSSON Sebastian                   0.004599                 NaN
# HOFER Lukas                                 NaN           -0.010365
# PIDRUCHNYI Dmytro                      0.001547            0.006945
# HORN Philipp                          -0.003387            0.006549
# BOE Tarjei                            -0.008838           -0.011555
# LAPSHIN Timofei                             NaN                 NaN
# BOE Johannes Thingnes                       NaN           -0.010933
# DUDCHENKO Anton                             NaN                 NaN
# PRYMA Artem                            0.008176                 NaN
# CLAUDE Fabien                          0.008511            0.012331
# LATYPOV Eduard                              NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# ILIEV Vladimir                              NaN                 NaN
# FEMLING Peppe                               NaN                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# REES Roman                            -0.011340                 NaN
# FAK Jakov                             -0.006998            0.005085
# NELIN Jesper                                NaN                 NaN
# SEPPALA Tero                                NaN            0.003196
# PEIFFER Arnd                          -0.001197            0.008610
# NAWRATH Philipp                       -0.006369                 NaN
# DOLL Benedikt                         -0.001467           -0.001166
# EBERHARD Julian                        0.006442           -0.001261
# NORDGREN Leif                               NaN                 NaN
# KRCMAR Michal                               NaN           -0.005020
# LEITNER Felix                               NaN            0.000451
# WINDISCH Dominik                      -0.002242           -0.009488
# DOLDER Mario                                NaN                 NaN
# ANEV Krasimir                               NaN                 NaN
# SCHEMPP Simon                               NaN            0.006000
# LESSER Erik                                 NaN                 NaN
# EDER Simon                                  NaN                 NaN
# WEGER Benjamin                              NaN                 NaN
# YALIOTNAU Raman                        0.000983                 NaN
# SMOLSKI Anton                               NaN                 NaN
# FILLON MAILLET Quentin                -0.005165           -0.010871
# CHENG Fangming                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# MALYSHKO Dmitry                             NaN           -0.002368
# ELISEEV Matvey                         0.013131            0.009399
# BAUER Klemen                                NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# BJOENTEGAARD Erlend                   -0.003416            0.007010
# BABIKOV Anton                               NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# STRELTSOV Kirill                            NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# STROLIA Vytautas                      -0.002695                 NaN
# LABASTAU Mikita                             NaN                 NaN
# FOURCADE Martin                       -0.004588           -0.013255
# KUEHN Johannes                        -0.000517            0.004305
# VARABEI Maksim                              NaN                 NaN
# WIESTNER Sera n                             NaN            0.000000
# RASTORGUJEVS Andrejs                  -0.001239           -0.005001
# LANGER Thierry                        -0.002028            0.001262
# LOGINOV Alexander                     -0.016231           -0.008460
# DESTHIEUX Simon                        0.004845           -0.013502
# DALE Johannes                         -0.013719           -0.008046
# BOCHARNIKOV Sergey                          NaN                 NaN
# GOW Scott                                   NaN                 NaN
# GARANICHEV Evgeniy                          NaN                 NaN
# CLAUDE Florent                              NaN                 NaN
# PONSILUOMA Martin                           NaN                 NaN
# DOHERTY Sean                           0.007689                 NaN
# GUIGONNAT Antonin                      0.003992           -0.007992
# JACQUELIN Emilien                     -0.012732            0.002241
# ANDERSEN Aleksander Fjeld                   NaN           -0.010874
#
#                              BT1920SWRLCP06SMMS  BT1920SWRLCP03SMMS  \
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                              NaN                 NaN
# CHRISTIANSEN Vetle Sjaastad            0.004359           -0.004036
# OTCENAS Martin                              NaN                 NaN
# SAMUELSSON Sebastian                        NaN                 NaN
# HOFER Lukas                            0.011083            0.001602
# PIDRUCHNYI Dmytro                     -0.018147           -0.027983
# HORN Philipp                           0.005503           -0.032426
# BOE Tarjei                             0.000394            0.022643
# LAPSHIN Timofei                             NaN           -0.058495
# BOE Johannes Thingnes                 -0.002643            0.035728
# DUDCHENKO Anton                             NaN                 NaN
# PRYMA Artem                           -0.018096                 NaN
# CLAUDE Fabien                               NaN            0.010456
# LATYPOV Eduard                              NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# ILIEV Vladimir                              NaN            0.008232
# FEMLING Peppe                               NaN                 NaN
# PORSHNEV Nikita                             NaN            0.006728
# REES Roman                                  NaN                 NaN
# FAK Jakov                              0.000266            0.005009
# NELIN Jesper                                NaN                 NaN
# SEPPALA Tero                                NaN                 NaN
# PEIFFER Arnd                          -0.012488            0.011172
# NAWRATH Philipp                        0.001497                 NaN
# DOLL Benedikt                          0.003984           -0.019747
# EBERHARD Julian                       -0.008920            0.013119
# NORDGREN Leif                               NaN                 NaN
# KRCMAR Michal                         -0.017859           -0.004652
# LEITNER Felix                               NaN            0.008710
# WINDISCH Dominik                      -0.003612            0.005239
# DOLDER Mario                                NaN                 NaN
# ANEV Krasimir                               NaN                 NaN
# SCHEMPP Simon                               NaN            0.007542
# LESSER Erik                            0.002082                 NaN
# EDER Simon                             0.012731            0.016301
# WEGER Benjamin                        -0.018505                 NaN
# YALIOTNAU Raman                             NaN                 NaN
# SMOLSKI Anton                               NaN                 NaN
# FILLON MAILLET Quentin                -0.004415            0.018246
# CHENG Fangming                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# MALYSHKO Dmitry                             NaN                 NaN
# ELISEEV Matvey                         0.004372           -0.077515
# BAUER Klemen                                NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# BJOENTEGAARD Erlend                    0.010367           -0.014092
# BABIKOV Anton                               NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# STRELTSOV Kirill                       0.009977                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# FOURCADE Martin                       -0.002168            0.006823
# KUEHN Johannes                         0.002971           -0.039334
# VARABEI Maksim                              NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# RASTORGUJEVS Andrejs                  -0.008081                 NaN
# LANGER Thierry                              NaN                 NaN
# LOGINOV Alexander                      0.000998            0.002682
# DESTHIEUX Simon                       -0.007973            0.018066
# DALE Johannes                          0.008279            0.006900
# BOCHARNIKOV Sergey                    -0.012694                 NaN
# GOW Scott                                   NaN                 NaN
# GARANICHEV Evgeniy                          NaN                 NaN
# CLAUDE Florent                              NaN           -0.013533
# PONSILUOMA Martin                           NaN           -0.012170
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                     -0.004899                 NaN
# JACQUELIN Emilien                     -0.009953            0.024440
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
#
#                              BT1920SWRLCP04SMMS  BT1920SWRLCP03SMSP
# BIRKELAND Lars Helge                        NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# MORAVEC Ondrej                        -0.000179                 NaN
# CHRISTIANSEN Vetle Sjaastad            0.006645           -0.002973
# OTCENAS Martin                              NaN                 NaN
# SAMUELSSON Sebastian                        NaN            0.002476
# HOFER Lukas                           -0.012508            0.005600
# PIDRUCHNYI Dmytro                     -0.002836            0.013573
# HORN Philipp                           0.008206            0.002260
# BOE Tarjei                            -0.009676            0.001154
# LAPSHIN Timofei                             NaN           -0.001491
# BOE Johannes Thingnes                       NaN            0.008848
# DUDCHENKO Anton                             NaN                 NaN
# PRYMA Artem                           -0.006237                 NaN
# CLAUDE Fabien                         -0.015368                 NaN
# LATYPOV Eduard                              NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# ILIEV Vladimir                        -0.007296           -0.012922
# FEMLING Peppe                               NaN                 NaN
# PORSHNEV Nikita                             NaN            0.001909
# REES Roman                                  NaN                 NaN
# FAK Jakov                              0.004715                 NaN
# NELIN Jesper                           0.010030                 NaN
# SEPPALA Tero                                NaN                 NaN
# PEIFFER Arnd                           0.001023           -0.014636
# NAWRATH Philipp                             NaN                 NaN
# DOLL Benedikt                         -0.000548            0.010223
# EBERHARD Julian                        0.001037            0.012354
# NORDGREN Leif                               NaN                 NaN
# KRCMAR Michal                          0.010212            0.005219
# LEITNER Felix                         -0.010607                 NaN
# WINDISCH Dominik                      -0.012623            0.005330
# DOLDER Mario                                NaN                 NaN
# ANEV Krasimir                               NaN                 NaN
# SCHEMPP Simon                         -0.041928                 NaN
# LESSER Erik                                 NaN                 NaN
# EDER Simon                             0.003058           -0.015980
# WEGER Benjamin                         0.014907                 NaN
# YALIOTNAU Raman                       -0.001090                 NaN
# SMOLSKI Anton                               NaN                 NaN
# FILLON MAILLET Quentin                -0.008066           -0.010670
# CHENG Fangming                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# MALYSHKO Dmitry                             NaN                 NaN
# ELISEEV Matvey                         0.018528           -0.002272
# BAUER Klemen                                NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# BJOENTEGAARD Erlend                    0.005039            0.004465
# BABIKOV Anton                               NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# STVRTECKY Jakub                             NaN           -0.010085
# STRELTSOV Kirill                            NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# FOURCADE Martin                       -0.005748           -0.009409
# KUEHN Johannes                         0.003410            0.003934
# VARABEI Maksim                              NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN                 NaN
# LANGER Thierry                              NaN                 NaN
# LOGINOV Alexander                      0.001328           -0.010577
# DESTHIEUX Simon                       -0.002442           -0.003954
# DALE Johannes                          0.004936           -0.006005
# BOCHARNIKOV Sergey                          NaN           -0.002799
# GOW Scott                                   NaN                 NaN
# GARANICHEV Evgeniy                          NaN           -0.007953
# CLAUDE Florent                              NaN            0.007027
# PONSILUOMA Martin                           NaN            0.005668
# DOHERTY Sean                                NaN                 NaN
# GUIGONNAT Antonin                           NaN                 NaN
# JACQUELIN Emilien                     -0.034437           -0.010476
# ANDERSEN Aleksander Fjeld                   NaN                 NaN

# %% [markdown]
# And these are the top improvers per competition (BT1920SWRLCH__SMSP is the one where Loginov won):

# %%
pandas.reset_option('display.max_rows')
pandas.concat((rel_improv.idxmax(), rel_improv.max()), axis=1, keys=["athlete", "improvement"])
# Out:
#                                   athlete  improvement
# BT1920SWRLCP02SMSP        LAPSHIN Timofei     0.016968
# BT1920SWRLCP06SMIN          DALE Johannes     0.014633
# BT1920SWRLCP01SMIN            HOFER Lukas     0.037008
# BT1920SWRLCP01SMSP         ILIEV Vladimir     0.016278
# BT1920SWRLCH__SMSP        LAPSHIN Timofei     0.027900
# BT1920SWRLCP03SMPU          SCHEMPP Simon     0.016954
# BT1920SWRLCP05SMPU              FAK Jakov     0.012332
# BT1920SWRLCP04SMSP         ELISEEV Matvey     0.032213
# BT1920SWRLCP05SMSP         ELISEEV Matvey     0.013131
# BT1920SWRLCP02SMPU          CLAUDE Fabien     0.012331
# BT1920SWRLCP06SMMS             EDER Simon     0.012731
# BT1920SWRLCP03SMMS  BOE Johannes Thingnes     0.035728
# BT1920SWRLCP04SMMS         ELISEEV Matvey     0.018528
# BT1920SWRLCP03SMSP      PIDRUCHNYI Dmytro     0.013573

# %% [markdown]
# In particular, Loginov was only 2.8% faster than his average in that race:

# %%
rel_improv["BT1920SWRLCH__SMSP"]["LOGINOV Alexander"]
# Out:
# 0.02782688256576994
