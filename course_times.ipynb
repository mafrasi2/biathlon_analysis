# %%
import biathlonresults
import itertools
import pandas
import requests
import shutil
from datetime import timedelta, datetime
from pathlib import Path
from tika import parser

# %%
events = biathlonresults.events(1920, 1)
competitions = {}
for event in events:
    competitions[event["EventId"]] = biathlonresults.competitions(event["EventId"])

# %% [markdown]
# We limit ourselves to men's competitions. Relays are a bit harder to compare than other competitions so we remove them as well:

# %%
men_non_relays = []
for _, comps in competitions.items():
    for comp in comps:
        desc = comp["Description"]
        if desc.startswith("Men") and not "Relay" in desc:
            men_non_relays.append(comp)

# %% [markdown]
# Download the analysis pdfs, which contain course times per athlete:

# %%
pdf_dir = Path("pdfs")
pdf_dir.mkdir(exist_ok=True)
pdfs = {}
if pdf_dir.exists(): # use cached pdfs
    for pdf in pdf_dir.iterdir():
        pdfs[pdf.stem] = pdf
else:
    for comp in men_non_relays:
        reports = biathlonresults.api._request("Reports2", {"RaceId": comp["RaceId"]})
        for report in reports["Reports"]:
            if report["Description"] == "COMPETITION ANALYSIS":
                break
        else:
            continue
        pdf_file = pdf_dir / f"{comp['RaceId']}.pdf"

        r = requests.get(report["URL"], stream=True)
        r.raise_for_status()
        with pdf_file.open("wb") as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
        pdfs[comp["RaceId"]] = pdf_file

# %% [markdown]
# Now parse the pdfs (this is ugly, but I don't know a better source for the course times):

# %%
def parse_pdf(pdf_file):
    raw_data = parser.from_file(str(pdf_file))
    next_rank = 1
    last_rank = None
    current_athlete = None
    course_times = {}
    for line in raw_data["content"].split("\n"):
        line = line.split()
        if not line:
            continue
        if line[0] == "Did":
            # Did not start and Did not finish
            break
        elif line[0] == f"{next_rank}" or line[0] == f"{last_rank}":
            if line[0] == f"{next_rank}":
                last_rank = next_rank
            next_rank += 1
            current_athlete = " ".join(line[2:-5])
        elif line[0] == "Course" and line[1] == "Time":
            if not current_athlete:
                assert current_athlete
            time = line[-3]
            try:
                time = datetime.strptime(time, "%H:%M:%S.%f")
            except ValueError:
                time = datetime.strptime(time, "%M:%S.%f")
            time = timedelta(hours=time.hour, minutes=time.minute, seconds=time.second, microseconds=time.microsecond)
            course_times[current_athlete] = time
            current_athlete = None
    return course_times
            
course_times = {}
for raceid, pdf in pdfs.items():
    course_times[raceid] = parse_pdf(pdf)

# %% [markdown]
# We want to compare the difference of the top athletes from the mean. For the athletes we are interested in, this difference would be higher in competitions with a large number of athletes, so we wouldn't be able to compare differences across competitions.
#
# Therefore, we have to limit the analysis to only the top 30 athletes in each competition:

# %%
top30 = {}
for comp, times in course_times.items():
    # works only for python 3.7+ since the dict must be ordered
    top30[comp] = dict(itertools.islice(times.items(), 30))

# %% [markdown]
# Now, we convert to pandas for easier analysis (athletes in rows and competitions in columns):

# %%
athletes = set()
athletes = athletes.union(*[athletes for _, athletes in top30.items()])
athletes = list(athletes) # we need an order
table = {}
athlete_rows = {}
for comp, times in top30.items():
    col = []
    for athlete in athletes:
        if athlete in times:
             # working with timedelta is a bit annoying in pandas, so we just use seconds
            time = times[athlete].total_seconds()
            col.append(time)
        else:
            col.append(None)
    table[comp] = col
df = pandas.DataFrame(table, index=athletes)
df
# Out:
#                      BT1920SWRLCP02SMSP  BT1920SWRLCP06SMIN  \
# BJOENTEGAARD Erlend              1437.5                 NaN
# LOGINOV Alexander                1409.2              2724.7
# STRELTSOV Kirill                    NaN              2844.7
# CLAUDE Florent                      NaN                 NaN
# FAK Jakov                        1433.0              2744.5
# ...                                 ...                 ...
# BAUER Klemen                     1465.1                 NaN
# DUDCHENKO Anton                  1465.1                 NaN
# ELISEEV Matvey                   1417.3                 NaN
# LEITNER Felix                    1424.9                 NaN
# CHENG Fangming                      NaN                 NaN
#
#                      BT1920SWRLCP01SMIN  BT1920SWRLCP01SMSP  \
# BJOENTEGAARD Erlend              3068.9              1346.3
# LOGINOV Alexander                3063.1              1358.3
# STRELTSOV Kirill                    NaN                 NaN
# CLAUDE Florent                   3117.9              1381.3
# FAK Jakov                           NaN              1390.4
# ...                                 ...                 ...
# BAUER Klemen                        NaN                 NaN
# DUDCHENKO Anton                     NaN                 NaN
# ELISEEV Matvey                   3121.0              1368.6
# LEITNER Felix                    3040.5                 NaN
# CHENG Fangming                   3111.8                 NaN
#
#                      BT1920SWRLCH__SMSP  BT1920SWRLCP03SMPU  \
# BJOENTEGAARD Erlend                 NaN              1600.8
# LOGINOV Alexander                1260.7              1679.5
# STRELTSOV Kirill                    NaN                 NaN
# CLAUDE Florent                      NaN              1668.1
# FAK Jakov                           NaN                 NaN
# ...                                 ...                 ...
# BAUER Klemen                        NaN                 NaN
# DUDCHENKO Anton                     NaN              1658.1
# ELISEEV Matvey                   1309.5              1729.7
# LEITNER Felix                    1304.4                 NaN
# CHENG Fangming                      NaN                 NaN
#
#                      BT1920SWRLCP05SMPU  BT1920SWRLCP04SMSP  \
# BJOENTEGAARD Erlend              1676.1              1431.4
# LOGINOV Alexander                1666.6              1449.0
# STRELTSOV Kirill                    NaN                 NaN
# CLAUDE Florent                      NaN                 NaN
# FAK Jakov                        1683.6              1500.0
# ...                                 ...                 ...
# BAUER Klemen                        NaN                 NaN
# DUDCHENKO Anton                  1728.4                 NaN
# ELISEEV Matvey                   1701.4              1447.0
# LEITNER Felix                       NaN                 NaN
# CHENG Fangming                      NaN              1484.9
#
#                      BT1920SWRLCP05SMSP  BT1920SWRLCP02SMPU  \
# BJOENTEGAARD Erlend              1279.7              1646.5
# LOGINOV Alexander                1305.5              1686.7
# STRELTSOV Kirill                    NaN                 NaN
# CLAUDE Florent                      NaN                 NaN
# FAK Jakov                        1307.8              1676.1
# ...                                 ...                 ...
# BAUER Klemen                        NaN                 NaN
# DUDCHENKO Anton                     NaN                 NaN
# ELISEEV Matvey                   1290.1              1699.4
# LEITNER Felix                       NaN              1674.5
# CHENG Fangming                      NaN                 NaN
#
#                      BT1920SWRLCP06SMMS  BT1920SWRLCP03SMMS  \
# BJOENTEGAARD Erlend              1970.7              2387.0
# LOGINOV Alexander                2010.3              2381.7
# STRELTSOV Kirill                 2057.4                 NaN
# CLAUDE Florent                      NaN              2471.2
# FAK Jakov                        2052.5              2391.8
# ...                                 ...                 ...
# BAUER Klemen                        NaN                 NaN
# DUDCHENKO Anton                     NaN                 NaN
# ELISEEV Matvey                   2047.6              2655.7
# LEITNER Felix                       NaN              2373.6
# CHENG Fangming                      NaN                 NaN
#
#                      BT1920SWRLCP04SMMS  BT1920SWRLCP03SMSP
# BJOENTEGAARD Erlend              2186.6              1319.6
# LOGINOV Alexander                2213.3              1349.4
# STRELTSOV Kirill                    NaN                 NaN
# CLAUDE Florent                      NaN              1350.8
# FAK Jakov                        2230.2                 NaN
# ...                                 ...                 ...
# BAUER Klemen                        NaN                 NaN
# DUDCHENKO Anton                     NaN                 NaN
# ELISEEV Matvey                   2218.2              1361.6
# LEITNER Felix                    2269.8                 NaN
# CHENG Fangming                      NaN                 NaN
#
# [73 rows x 14 columns]

# %% [markdown]
# Construct the relative distance from the mean in each competition per athlete and then the mean per athlete across all competitions:

# %%
diff_from_mean = df-df.mean()
rel_per_comp_and_athlete = diff_from_mean / df.mean()
rel_mean_per_athlete = rel_per_comp_and_athlete.mean(axis=1)

# %% [markdown]
# For example, Johannes is on average 2.8% faster than the mean athlete:

# %%
rel_mean_per_athlete.sort_values()
# Out:
# BOE Johannes Thingnes    -0.027684
# FILLON MAILLET Quentin   -0.022864
# FOURCADE Martin          -0.022447
# KUEHN Johannes           -0.016629
# BOE Tarjei               -0.016537
#                             ...
# LANDERTINGER Dominik      0.032851
# GUZIK Grzegorz            0.035970
# LAPSHIN Timofei           0.035998
# BAUER Klemen              0.036923
# BABIKOV Anton             0.044892
# Length: 73, dtype: float64

# %% [markdown]
# Now, let's see how much have they differed from their own mean per competition:

# %%
rel_improv = (-1*rel_per_comp_and_athlete).add(rel_mean_per_athlete, axis=0)

# %% [markdown]
# For example, Matvey Eliseev was 1.3% better than his average in BT1920SWRLCP02SMSP (sprint in Hochfilzen):

# %%
pandas.set_option('display.max_rows', len(rel_improv))
rel_improv
# Out:
#                              BT1920SWRLCP02SMSP  BT1920SWRLCP06SMIN  \
# BJOENTEGAARD Erlend                   -0.030432                 NaN
# LOGINOV Alexander                     -0.001370            0.001130
# STRELTSOV Kirill                            NaN           -0.011008
# CLAUDE Florent                              NaN                 NaN
# FAK Jakov                             -0.007233            0.004882
# MALYSHKO Dmitry                        0.002582                 NaN
# STROLIA Vytautas                            NaN                 NaN
# NAWRATH Philipp                             NaN            0.006778
# LANGER Thierry                         0.002027                 NaN
# LATYPOV Eduard                              NaN           -0.006687
# DOLL Benedikt                          0.003627            0.006247
# BOE Tarjei                             0.003442            0.001090
# WINDISCH Dominik                       0.004026                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# PEIFFER Arnd                          -0.006864                 NaN
# KRCMAR Michal                               NaN                 NaN
# GUIGONNAT Antonin                     -0.001933            0.005636
# YALIOTNAU Raman                             NaN                 NaN
# ILIEV Vladimir                              NaN            0.003782
# PRYMA Artem                                 NaN            0.012191
# GARANICHEV Evgeniy                          NaN                 NaN
# SMOLSKI Anton                               NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN           -0.001813
# NELIN Jesper                                NaN                 NaN
# JACQUELIN Emilien                     -0.007915                 NaN
# SCHEMPP Simon                          0.017361                 NaN
# MORAVEC Ondrej                              NaN            0.008175
# VACLAVIK Adam                               NaN                 NaN
# WEGER Benjamin                              NaN           -0.003559
# BOCHARNIKOV Sergey                          NaN            0.000110
# DOLDER Mario                                NaN                 NaN
# HORN Philipp                           0.000256            0.007930
# HOFER Lukas                            0.002554           -0.008619
# BABIKOV Anton                               NaN                 NaN
# LAPSHIN Timofei                        0.020378                 NaN
# SEPPALA Tero                                NaN                 NaN
# BIRKELAND Lars Helge                        NaN                 NaN
# STVRTECKY Jakub                        0.010085                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# PIDRUCHNYI Dmytro                      0.008083           -0.009472
# SAMUELSSON Sebastian                        NaN                 NaN
# EDER Simon                                  NaN           -0.005743
# ANEV Krasimir                               NaN                 NaN
# FILLON MAILLET Quentin                 0.003414            0.011814
# DESTHIEUX Simon                        0.007510           -0.002666
# REES Roman                                  NaN                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# PONSILUOMA Martin                           NaN                 NaN
# GOW Scott                                   NaN            0.002168
# CLAUDE Fabien                         -0.005669            0.005566
# EBERHARD Julian                       -0.007465                 NaN
# CHRISTIANSEN Vetle Sjaastad           -0.014532           -0.007285
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# KUEHN Johannes                         0.001652           -0.002799
# FEMLING Peppe                               NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# FOURCADE Martin                       -0.006431            0.004746
# DOHERTY Sean                                NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# NORDGREN Leif                               NaN            0.006340
# VARABEI Maksim                              NaN            0.000000
# OTCENAS Martin                              NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# LESSER Erik                                 NaN           -0.006020
# BOE Johannes Thingnes                 -0.001264           -0.000673
# DALE Johannes                         -0.006610            0.014242
# BAUER Klemen                           0.000000                 NaN
# DUDCHENKO Anton                       -0.014017                 NaN
# ELISEEV Matvey                         0.012888                 NaN
# LEITNER Felix                         -0.008162                 NaN
# CHENG Fangming                              NaN                 NaN
#
#                              BT1920SWRLCP01SMIN  BT1920SWRLCP01SMSP  \
# BJOENTEGAARD Erlend                   -0.011725            0.001876
# LOGINOV Alexander                     -0.000804            0.002129
# STRELTSOV Kirill                            NaN                 NaN
# CLAUDE Florent                         0.000642            0.004580
# FAK Jakov                                   NaN           -0.010377
# MALYSHKO Dmitry                             NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# NAWRATH Philipp                             NaN                 NaN
# LANGER Thierry                              NaN                 NaN
# LATYPOV Eduard                              NaN            0.006687
# DOLL Benedikt                          0.016981            0.007637
# BOE Tarjei                             0.006096            0.011625
# WINDISCH Dominik                            NaN                 NaN
# BORMOLINI Thomas                      -0.001949            0.001949
# WIESTNER Sera n                             NaN                 NaN
# PEIFFER Arnd                                NaN                 NaN
# KRCMAR Michal                          0.009173           -0.008487
# GUIGONNAT Antonin                           NaN           -0.006108
# YALIOTNAU Raman                             NaN           -0.006952
# ILIEV Vladimir                              NaN            0.017587
# PRYMA Artem                                 NaN                 NaN
# GARANICHEV Evgeniy                     0.017691           -0.023469
# SMOLSKI Anton                               NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN            0.003391
# NELIN Jesper                                NaN                 NaN
# JACQUELIN Emilien                      0.009834            0.007034
# SCHEMPP Simon                               NaN                 NaN
# MORAVEC Ondrej                        -0.005963                 NaN
# VACLAVIK Adam                               NaN            0.000000
# WEGER Benjamin                         0.007112                 NaN
# BOCHARNIKOV Sergey                          NaN            0.009857
# DOLDER Mario                                NaN            0.000000
# HORN Philipp                          -0.016025                 NaN
# HOFER Lukas                            0.038638           -0.019303
# BABIKOV Anton                          0.000000                 NaN
# LAPSHIN Timofei                             NaN                 NaN
# SEPPALA Tero                          -0.004516                 NaN
# BIRKELAND Lars Helge                        NaN           -0.001716
# STVRTECKY Jakub                             NaN                 NaN
# LANDERTINGER Dominik                   0.000000                 NaN
# PIDRUCHNYI Dmytro                      0.008593                 NaN
# SAMUELSSON Sebastian                  -0.020322            0.003655
# EDER Simon                             0.005383                 NaN
# ANEV Krasimir                         -0.020967                 NaN
# FILLON MAILLET Quentin                 0.023687           -0.009189
# DESTHIEUX Simon                        0.027642           -0.002678
# REES Roman                                  NaN                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# PONSILUOMA Martin                      0.007465                 NaN
# GOW Scott                                   NaN                 NaN
# CLAUDE Fabien                          0.005873           -0.008673
# EBERHARD Julian                       -0.020073            0.007779
# CHRISTIANSEN Vetle Sjaastad                 NaN                 NaN
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# KUEHN Johannes                              NaN            0.010729
# FEMLING Peppe                               NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# FOURCADE Martin                        0.025243            0.010764
# DOHERTY Sean                                NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# NORDGREN Leif                               NaN                 NaN
# VARABEI Maksim                              NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# LESSER Erik                                 NaN                 NaN
# BOE Johannes Thingnes                 -0.026171            0.006625
# DALE Johannes                               NaN           -0.002161
# BAUER Klemen                                NaN                 NaN
# DUDCHENKO Anton                             NaN                 NaN
# ELISEEV Matvey                         0.000344            0.014583
# LEITNER Felix                          0.010870                 NaN
# CHENG Fangming                        -0.002473                 NaN
#
#                              BT1920SWRLCH__SMSP  BT1920SWRLCP03SMPU  \
# BJOENTEGAARD Erlend                         NaN            0.013430
# LOGINOV Alexander                      0.027041           -0.025398
# STRELTSOV Kirill                            NaN                 NaN
# CLAUDE Florent                              NaN            0.000814
# FAK Jakov                                   NaN                 NaN
# MALYSHKO Dmitry                             NaN                 NaN
# STROLIA Vytautas                       0.001653                 NaN
# NAWRATH Philipp                             NaN                 NaN
# LANGER Thierry                              NaN                 NaN
# LATYPOV Eduard                              NaN                 NaN
# DOLL Benedikt                          0.011016           -0.012433
# BOE Tarjei                             0.002600           -0.006667
# WINDISCH Dominik                            NaN            0.015215
# BORMOLINI Thomas                            NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# PEIFFER Arnd                           0.002196           -0.000244
# KRCMAR Michal                               NaN            0.014323
# GUIGONNAT Antonin                           NaN                 NaN
# YALIOTNAU Raman                             NaN                 NaN
# ILIEV Vladimir                              NaN           -0.009258
# PRYMA Artem                           -0.006881            0.005101
# GARANICHEV Evgeniy                          NaN                 NaN
# SMOLSKI Anton                          0.003557                 NaN
# RASTORGUJEVS Andrejs                        NaN                 NaN
# NELIN Jesper                          -0.004210                 NaN
# JACQUELIN Emilien                      0.012914            0.009260
# SCHEMPP Simon                               NaN            0.013954
# MORAVEC Ondrej                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# WEGER Benjamin                              NaN                 NaN
# BOCHARNIKOV Sergey                          NaN                 NaN
# DOLDER Mario                                NaN                 NaN
# HORN Philipp                           0.020327           -0.003959
# HOFER Lukas                           -0.006896            0.009641
# BABIKOV Anton                               NaN                 NaN
# LAPSHIN Timofei                        0.031309            0.007433
# SEPPALA Tero                                NaN                 NaN
# BIRKELAND Lars Helge                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# PIDRUCHNYI Dmytro                      0.009886            0.012619
# SAMUELSSON Sebastian                   0.007252                 NaN
# EDER Simon                                  NaN            0.000243
# ANEV Krasimir                          0.020967                 NaN
# FILLON MAILLET Quentin                 0.016487           -0.015183
# DESTHIEUX Simon                       -0.013068           -0.005675
# REES Roman                                  NaN                 NaN
# PORSHNEV Nikita                       -0.009004                 NaN
# PONSILUOMA Martin                      0.007663           -0.011971
# GOW Scott                             -0.000558                 NaN
# CLAUDE Fabien                               NaN                 NaN
# EBERHARD Julian                       -0.001476           -0.001610
# CHRISTIANSEN Vetle Sjaastad                 NaN            0.008587
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
# TRSAN Rok                             -0.000454            0.000454
# KUEHN Johannes                              NaN            0.001087
# FEMLING Peppe                          0.000000                 NaN
# GUZIK Grzegorz                         0.000000                 NaN
# FOURCADE Martin                       -0.002310           -0.006860
# DOHERTY Sean                                NaN                 NaN
# LABASTAU Mikita                             NaN           -0.005232
# NORDGREN Leif                               NaN                 NaN
# VARABEI Maksim                              NaN                 NaN
# OTCENAS Martin                         0.000000                 NaN
# YEREMIN Roman                               NaN                 NaN
# LESSER Erik                                 NaN                 NaN
# BOE Johannes Thingnes                 -0.001399            0.003593
# DALE Johannes                         -0.003009           -0.003813
# BAUER Klemen                                NaN                 NaN
# DUDCHENKO Anton                             NaN            0.014532
# ELISEEV Matvey                         0.009525           -0.035937
# LEITNER Felix                         -0.002226                 NaN
# CHENG Fangming                              NaN                 NaN
#
#                              BT1920SWRLCP05SMPU  BT1920SWRLCP04SMSP  \
# BJOENTEGAARD Erlend                   -0.005497            0.015568
# LOGINOV Alexander                      0.009161            0.012658
# STRELTSOV Kirill                            NaN                 NaN
# CLAUDE Florent                              NaN                 NaN
# FAK Jakov                              0.010076           -0.010972
# MALYSHKO Dmitry                             NaN                 NaN
# STROLIA Vytautas                            NaN            0.001042
# NAWRATH Philipp                        0.004702                 NaN
# LANGER Thierry                              NaN                 NaN
# LATYPOV Eduard                              NaN                 NaN
# DOLL Benedikt                         -0.024314                 NaN
# BOE Tarjei                             0.003798           -0.004146
# WINDISCH Dominik                            NaN                 NaN
# BORMOLINI Thomas                            NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# PEIFFER Arnd                           0.001610            0.003915
# KRCMAR Michal                         -0.010862                 NaN
# GUIGONNAT Antonin                      0.012867                 NaN
# YALIOTNAU Raman                        0.003006           -0.000764
# ILIEV Vladimir                              NaN                 NaN
# PRYMA Artem                            0.011742           -0.000359
# GARANICHEV Evgeniy                     0.005798            0.007616
# SMOLSKI Anton                               NaN           -0.003557
# RASTORGUJEVS Andrejs                  -0.002685            0.008393
# NELIN Jesper                                NaN           -0.011197
# JACQUELIN Emilien                      0.014161            0.018936
# SCHEMPP Simon                               NaN                 NaN
# MORAVEC Ondrej                        -0.002783            0.001312
# VACLAVIK Adam                               NaN                 NaN
# WEGER Benjamin                              NaN           -0.000271
# BOCHARNIKOV Sergey                          NaN            0.011286
# DOLDER Mario                                NaN                 NaN
# HORN Philipp                                NaN           -0.001996
# HOFER Lukas                                 NaN                 NaN
# BABIKOV Anton                               NaN                 NaN
# LAPSHIN Timofei                             NaN                 NaN
# SEPPALA Tero                                NaN                 NaN
# BIRKELAND Lars Helge                   0.001716                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# PIDRUCHNYI Dmytro                           NaN                 NaN
# SAMUELSSON Sebastian                   0.001107                 NaN
# EDER Simon                                  NaN           -0.017553
# ANEV Krasimir                               NaN                 NaN
# FILLON MAILLET Quentin                -0.016148            0.002286
# DESTHIEUX Simon                       -0.014544            0.003573
# REES Roman                             0.008536                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# PONSILUOMA Martin                           NaN                 NaN
# GOW Scott                                   NaN           -0.001610
# CLAUDE Fabien                         -0.008922                 NaN
# EBERHARD Julian                       -0.002863                 NaN
# CHRISTIANSEN Vetle Sjaastad           -0.013012            0.006314
# ANDERSEN Aleksander Fjeld              0.009284                 NaN
# TRSAN Rok                                   NaN                 NaN
# KUEHN Johannes                        -0.001800            0.012729
# FEMLING Peppe                               NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# FOURCADE Martin                       -0.015671            0.015800
# DOHERTY Sean                                NaN           -0.007689
# LABASTAU Mikita                        0.005232                 NaN
# NORDGREN Leif                               NaN           -0.006340
# VARABEI Maksim                              NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# YEREMIN Roman                               NaN            0.000000
# LESSER Erik                                 NaN                 NaN
# BOE Johannes Thingnes                       NaN                 NaN
# DALE Johannes                          0.002869            0.009052
# BAUER Klemen                                NaN                 NaN
# DUDCHENKO Anton                       -0.000516                 NaN
# ELISEEV Matvey                         0.008546            0.034005
# LEITNER Felix                               NaN                 NaN
# CHENG Fangming                              NaN            0.002473
#
#                              BT1920SWRLCP05SMSP  BT1920SWRLCP02SMPU  \
# BJOENTEGAARD Erlend                   -0.006031            0.006320
# LOGINOV Alexander                     -0.017017           -0.008590
# STRELTSOV Kirill                            NaN                 NaN
# CLAUDE Florent                              NaN                 NaN
# FAK Jakov                             -0.007821            0.008705
# MALYSHKO Dmitry                             NaN           -0.002582
# STROLIA Vytautas                      -0.002695                 NaN
# NAWRATH Philipp                       -0.003107                 NaN
# LANGER Thierry                        -0.000767           -0.001260
# LATYPOV Eduard                              NaN                 NaN
# DOLL Benedikt                         -0.001073           -0.008445
# BOE Tarjei                            -0.008129           -0.008968
# WINDISCH Dominik                      -0.001755           -0.009852
# BORMOLINI Thomas                            NaN                 NaN
# WIESTNER Sera n                             NaN            0.000000
# PEIFFER Arnd                          -0.002058            0.006211
# KRCMAR Michal                               NaN           -0.003777
# GUIGONNAT Antonin                      0.003130           -0.009626
# YALIOTNAU Raman                       -0.000984                 NaN
# ILIEV Vladimir                              NaN                 NaN
# PRYMA Artem                            0.007732                 NaN
# GARANICHEV Evgeniy                          NaN                 NaN
# SMOLSKI Anton                               NaN                 NaN
# RASTORGUJEVS Andrejs                  -0.002757           -0.000779
# NELIN Jesper                                NaN                 NaN
# JACQUELIN Emilien                     -0.009444            0.008966
# SCHEMPP Simon                               NaN            0.006282
# MORAVEC Ondrej                        -0.003356                 NaN
# VACLAVIK Adam                               NaN                 NaN
# WEGER Benjamin                              NaN                 NaN
# BOCHARNIKOV Sergey                          NaN                 NaN
# DOLDER Mario                                NaN                 NaN
# HORN Philipp                          -0.004538            0.010708
# HOFER Lukas                                 NaN           -0.007344
# BABIKOV Anton                               NaN                 NaN
# LAPSHIN Timofei                             NaN                 NaN
# SEPPALA Tero                                NaN            0.004516
# BIRKELAND Lars Helge                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# PIDRUCHNYI Dmytro                      0.001386            0.005031
# SAMUELSSON Sebastian                   0.005216                 NaN
# EDER Simon                                  NaN                 NaN
# ANEV Krasimir                               NaN                 NaN
# FILLON MAILLET Quentin                -0.003437           -0.012435
# DESTHIEUX Simon                        0.003269           -0.009978
# REES Roman                            -0.008536                 NaN
# PORSHNEV Nikita                             NaN                 NaN
# PONSILUOMA Martin                           NaN                 NaN
# GOW Scott                                   NaN                 NaN
# CLAUDE Fabien                          0.008817            0.011783
# EBERHARD Julian                        0.004388           -0.000094
# CHRISTIANSEN Vetle Sjaastad            0.009540                 NaN
# ANDERSEN Aleksander Fjeld                   NaN           -0.009284
# TRSAN Rok                                   NaN                 NaN
# KUEHN Johannes                        -0.001857            0.008511
# FEMLING Peppe                               NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# FOURCADE Martin                       -0.003330           -0.013924
# DOHERTY Sean                           0.007689                 NaN
# LABASTAU Mikita                             NaN                 NaN
# NORDGREN Leif                               NaN                 NaN
# VARABEI Maksim                              NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# LESSER Erik                                 NaN                 NaN
# BOE Johannes Thingnes                       NaN           -0.021127
# DALE Johannes                         -0.014110           -0.015625
# BAUER Klemen                                NaN                 NaN
# DUDCHENKO Anton                             NaN                 NaN
# ELISEEV Matvey                         0.014923            0.003837
# LEITNER Felix                               NaN            0.002996
# CHENG Fangming                              NaN                 NaN
#
#                              BT1920SWRLCP06SMMS  BT1920SWRLCP03SMMS  \
# BJOENTEGAARD Erlend                    0.013140           -0.006189
# LOGINOV Alexander                      0.002605            0.005050
# STRELTSOV Kirill                       0.011008                 NaN
# CLAUDE Florent                              NaN           -0.012909
# FAK Jakov                             -0.007267            0.011828
# MALYSHKO Dmitry                             NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# NAWRATH Philipp                       -0.008372                 NaN
# LANGER Thierry                              NaN                 NaN
# LATYPOV Eduard                              NaN                 NaN
# DOLL Benedikt                          0.008981           -0.020131
# BOE Tarjei                             0.000455            0.018942
# WINDISCH Dominik                      -0.002108            0.006524
# BORMOLINI Thomas                            NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# PEIFFER Arnd                          -0.015511            0.014458
# KRCMAR Michal                         -0.011621           -0.006139
# GUIGONNAT Antonin                     -0.003966                 NaN
# YALIOTNAU Raman                             NaN                 NaN
# ILIEV Vladimir                              NaN            0.012630
# PRYMA Artem                           -0.018925                 NaN
# GARANICHEV Evgeniy                          NaN                 NaN
# SMOLSKI Anton                               NaN                 NaN
# RASTORGUJEVS Andrejs                  -0.003750                 NaN
# NELIN Jesper                                NaN                 NaN
# JACQUELIN Emilien                     -0.010864            0.023811
# SCHEMPP Simon                               NaN            0.004654
# MORAVEC Ondrej                              NaN                 NaN
# VACLAVIK Adam                               NaN                 NaN
# WEGER Benjamin                        -0.020426                 NaN
# BOCHARNIKOV Sergey                    -0.020373                 NaN
# DOLDER Mario                                NaN                 NaN
# HORN Philipp                           0.008134           -0.035257
# HOFER Lukas                            0.005846           -0.000318
# BABIKOV Anton                               NaN                 NaN
# LAPSHIN Timofei                             NaN           -0.061040
# SEPPALA Tero                                NaN                 NaN
# BIRKELAND Lars Helge                        NaN                 NaN
# STVRTECKY Jakub                             NaN                 NaN
# LANDERTINGER Dominik                        NaN                 NaN
# PIDRUCHNYI Dmytro                     -0.023426           -0.028096
# SAMUELSSON Sebastian                        NaN                 NaN
# EDER Simon                             0.009294            0.020118
# ANEV Krasimir                               NaN                 NaN
# FILLON MAILLET Quentin                -0.000288            0.015527
# DESTHIEUX Simon                       -0.005316            0.017492
# REES Roman                                  NaN                 NaN
# PORSHNEV Nikita                             NaN            0.007462
# PONSILUOMA Martin                           NaN           -0.009198
# GOW Scott                                   NaN                 NaN
# CLAUDE Fabien                               NaN            0.010702
# EBERHARD Julian                       -0.007538            0.011843
# CHRISTIANSEN Vetle Sjaastad            0.010099           -0.005293
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# KUEHN Johannes                        -0.005319           -0.030079
# FEMLING Peppe                               NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# FOURCADE Martin                       -0.000662            0.005501
# DOHERTY Sean                                NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# NORDGREN Leif                               NaN                 NaN
# VARABEI Maksim                              NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# LESSER Erik                            0.006020                 NaN
# BOE Johannes Thingnes                  0.003589            0.026102
# DALE Johannes                          0.004860            0.011135
# BAUER Klemen                                NaN                 NaN
# DUDCHENKO Anton                             NaN                 NaN
# ELISEEV Matvey                         0.004164           -0.088962
# LEITNER Felix                               NaN            0.012739
# CHENG Fangming                              NaN                 NaN
#
#                              BT1920SWRLCP04SMMS  BT1920SWRLCP03SMSP
# BJOENTEGAARD Erlend                    0.007691            0.001850
# LOGINOV Alexander                      0.004767           -0.011363
# STRELTSOV Kirill                            NaN                 NaN
# CLAUDE Florent                              NaN            0.006872
# FAK Jakov                              0.008179                 NaN
# MALYSHKO Dmitry                             NaN                 NaN
# STROLIA Vytautas                            NaN                 NaN
# NAWRATH Philipp                             NaN                 NaN
# LANGER Thierry                              NaN                 NaN
# LATYPOV Eduard                              NaN                 NaN
# DOLL Benedikt                          0.001290            0.010617
# BOE Tarjei                            -0.022003            0.001864
# WINDISCH Dominik                      -0.017868            0.005818
# BORMOLINI Thomas                            NaN                 NaN
# WIESTNER Sera n                             NaN                 NaN
# PEIFFER Arnd                           0.011784           -0.015497
# KRCMAR Michal                          0.014491            0.002900
# GUIGONNAT Antonin                           NaN                 NaN
# YALIOTNAU Raman                        0.005695                 NaN
# ILIEV Vladimir                        -0.013128           -0.011613
# PRYMA Artem                           -0.010601                 NaN
# GARANICHEV Evgeniy                          NaN           -0.007637
# SMOLSKI Anton                               NaN                 NaN
# RASTORGUJEVS Andrejs                        NaN                 NaN
# NELIN Jesper                           0.015407                 NaN
# JACQUELIN Emilien                     -0.069507           -0.007187
# SCHEMPP Simon                         -0.042251                 NaN
# MORAVEC Ondrej                         0.002614                 NaN
# VACLAVIK Adam                               NaN                 NaN
# WEGER Benjamin                         0.017143                 NaN
# BOCHARNIKOV Sergey                          NaN           -0.000880
# DOLDER Mario                                NaN                 NaN
# HORN Philipp                           0.013310            0.001109
# HOFER Lukas                           -0.021428            0.007230
# BABIKOV Anton                               NaN                 NaN
# LAPSHIN Timofei                             NaN            0.001919
# SEPPALA Tero                                NaN                 NaN
# BIRKELAND Lars Helge                        NaN                 NaN
# STVRTECKY Jakub                             NaN           -0.010085
# LANDERTINGER Dominik                        NaN                 NaN
# PIDRUCHNYI Dmytro                      0.001983            0.013412
# SAMUELSSON Sebastian                        NaN            0.003093
# EDER Simon                             0.005367           -0.017110
# ANEV Krasimir                               NaN                 NaN
# FILLON MAILLET Quentin                -0.007594           -0.008942
# DESTHIEUX Simon                       -0.000032           -0.005530
# REES Roman                                  NaN                 NaN
# PORSHNEV Nikita                             NaN            0.001542
# PONSILUOMA Martin                           NaN            0.006041
# GOW Scott                                   NaN                 NaN
# CLAUDE Fabien                         -0.019477                 NaN
# EBERHARD Julian                        0.006809            0.010300
# CHRISTIANSEN Vetle Sjaastad            0.009743           -0.004161
# ANDERSEN Aleksander Fjeld                   NaN                 NaN
# TRSAN Rok                                   NaN                 NaN
# KUEHN Johannes                         0.004553            0.002594
# FEMLING Peppe                               NaN                 NaN
# GUZIK Grzegorz                              NaN                 NaN
# FOURCADE Martin                       -0.004714           -0.008151
# DOHERTY Sean                                NaN                 NaN
# LABASTAU Mikita                             NaN                 NaN
# NORDGREN Leif                               NaN                 NaN
# VARABEI Maksim                              NaN                 NaN
# OTCENAS Martin                              NaN                 NaN
# YEREMIN Roman                               NaN                 NaN
# LESSER Erik                                 NaN                 NaN
# BOE Johannes Thingnes                       NaN            0.010724
# DALE Johannes                          0.009567           -0.006396
# BAUER Klemen                                NaN                 NaN
# DUDCHENKO Anton                             NaN                 NaN
# ELISEEV Matvey                         0.022563           -0.000480
# LEITNER Felix                         -0.016217                 NaN
# CHENG Fangming                              NaN                 NaN

# %% [markdown]
# And these are the top improvers per competition (BT1920SWRLCH__SMSP is the one where Loginov won):

# %%
pandas.reset_option('display.max_rows')
pandas.concat((rel_improv.idxmax(), rel_improv.max()), axis=1, keys=["athlete", "improvement"])
# Out:
#                                   athlete  improvement
# BT1920SWRLCP02SMSP        LAPSHIN Timofei     0.020378
# BT1920SWRLCP06SMIN          DALE Johannes     0.014242
# BT1920SWRLCP01SMIN            HOFER Lukas     0.038638
# BT1920SWRLCP01SMSP         ILIEV Vladimir     0.017587
# BT1920SWRLCH__SMSP        LAPSHIN Timofei     0.031309
# BT1920SWRLCP03SMPU       WINDISCH Dominik     0.015215
# BT1920SWRLCP05SMPU      JACQUELIN Emilien     0.014161
# BT1920SWRLCP04SMSP         ELISEEV Matvey     0.034005
# BT1920SWRLCP05SMSP         ELISEEV Matvey     0.014923
# BT1920SWRLCP02SMPU          CLAUDE Fabien     0.011783
# BT1920SWRLCP06SMMS    BJOENTEGAARD Erlend     0.013140
# BT1920SWRLCP03SMMS  BOE Johannes Thingnes     0.026102
# BT1920SWRLCP04SMMS         ELISEEV Matvey     0.022563
# BT1920SWRLCP03SMSP      PIDRUCHNYI Dmytro     0.013412

# %% [markdown]
# In particular, Loginov was only 2.7% faster than his average in that race:

# %%
rel_improv["BT1920SWRLCH__SMSP"]["LOGINOV Alexander"]
# Out:
# 0.02704111923107036
